# %%
import cv2
import matplotlib.pyplot as plt

# Load the input image
image_path ="E://1_DATASET//MICC//MICC_F600//_r30_s1200berries.png"
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Check if the image is loaded
if image is None:
    print("Error: Image not loaded. Please check the path.")
    exit()

# Create an ORB detector
orb = cv2.ORB_create()

# Detect keypoints and compute descriptors
keypoints, descriptors = orb.detectAndCompute(image, None)

# Draw the keypoints on the image
keypoints_image = cv2.drawKeypoints(image, keypoints, None, color=(0, 255, 0), flags=0)

# Display the original image with keypoints
plt.figure(figsize=(10, 6))
plt.title("ORB Keypoints")
plt.imshow(keypoints_image, cmap='gray')
plt.axis("off")
plt.show()

# Print the number of keypoints and descriptors
print(f"Number of keypoints detected: {len(keypoints)}")
if descriptors is not None:
    print(f"Descriptor shape: {descriptors.shape}")
else:
    print("No descriptors computed.")
# Out:
# Number of keypoints detected: 500
# Descriptor shape: (500, 32)

# %%
print(keypoints)
# Out:
# (< cv2.KeyPoint 000001F3384F0E40>, < cv2.KeyPoint 000001F3384F0E70>, < cv2.KeyPoint 000001F3384F0990>, < cv2.KeyPoint 000001F3384F0E10>, < cv2.KeyPoint 000001F3384F0BD0>, < cv2.KeyPoint 000001F3384F01E0>, < cv2.KeyPoint 000001F3384F0CC0>, < cv2.KeyPoint 000001F340C79C30>, < cv2.KeyPoint 000001F340C79D20>, < cv2.KeyPoint 000001F340BC3210>, < cv2.KeyPoint 000001F3413729F0>, < cv2.KeyPoint 000001F34136A3C0>, < cv2.KeyPoint 000001F3413A49C0>, < cv2.KeyPoint 000001F3413A4E10>, < cv2.KeyPoint 000001F3413A4CF0>, < cv2.KeyPoint 000001F3413B0060>, < cv2.KeyPoint 000001F3413B00C0>, < cv2.KeyPoint 000001F3413B00F0>, < cv2.KeyPoint 000001F3413B01E0>, < cv2.KeyPoint 000001F3413B0180>, < cv2.KeyPoint 000001F3413B0240>, < cv2.KeyPoint 000001F3413B0210>, < cv2.KeyPoint 000001F3413B0270>, < cv2.KeyPoint 000001F3413B02A0>, < cv2.KeyPoint 000001F3413B0390>, < cv2.KeyPoint 000001F3413B02D0>, < cv2.KeyPoint 000001F3413B0300>, < cv2.KeyPoint 000001F3413B0360>, < cv2.KeyPoint 000001F3413B0330>, < cv2.KeyPoint 000001F3413B0030>, < cv2.KeyPoint 000001F3413B01B0>, < cv2.KeyPoint 000001F3413B03C0>, < cv2.KeyPoint 000001F3413B0420>, < cv2.KeyPoint 000001F3413B03F0>, < cv2.KeyPoint 000001F3413B0450>, < cv2.KeyPoint 000001F3413B0480>, < cv2.KeyPoint 000001F3413B04B0>, < cv2.KeyPoint 000001F3413B04E0>, < cv2.KeyPoint 000001F3413B0510>, < cv2.KeyPoint 000001F3413B0540>, < cv2.KeyPoint 000001F3413B0570>, < cv2.KeyPoint 000001F3413B05A0>, < cv2.KeyPoint 000001F3413B05D0>, < cv2.KeyPoint 000001F3413B0600>, < cv2.KeyPoint 000001F3413B0630>, < cv2.KeyPoint 000001F3413B0660>, < cv2.KeyPoint 000001F3413B0690>, < cv2.KeyPoint 000001F3413B06C0>, < cv2.KeyPoint 000001F3413B06F0>, < cv2.KeyPoint 000001F3413B0720>, < cv2.KeyPoint 000001F3413B0750>, < cv2.KeyPoint 000001F3413B0780>, < cv2.KeyPoint 000001F3413B07B0>, < cv2.KeyPoint 000001F3413B07E0>, < cv2.KeyPoint 000001F3413B0810>, < cv2.KeyPoint 000001F3413B0840>, < cv2.KeyPoint 000001F3413B0870>, < cv2.KeyPoint 000001F3413B08A0>, < cv2.KeyPoint 000001F3413B08D0>, < cv2.KeyPoint 000001F3413B0900>, < cv2.KeyPoint 000001F3413B0930>, < cv2.KeyPoint 000001F3413B0960>, < cv2.KeyPoint 000001F3413B0990>, < cv2.KeyPoint 000001F3413B09C0>, < cv2.KeyPoint 000001F3413B09F0>, < cv2.KeyPoint 000001F3413B0A20>, < cv2.KeyPoint 000001F3413B0A50>, < cv2.KeyPoint 000001F3413B0A80>, < cv2.KeyPoint 000001F3413B0AB0>, < cv2.KeyPoint 000001F3413B0AE0>, < cv2.KeyPoint 000001F3413B0B10>, < cv2.KeyPoint 000001F3413B0B40>, < cv2.KeyPoint 000001F3413B0B70>, < cv2.KeyPoint 000001F3413B0BA0>, < cv2.KeyPoint 000001F3413B0BD0>, < cv2.KeyPoint 000001F3413B0C00>, < cv2.KeyPoint 000001F3413B0C30>, < cv2.KeyPoint 000001F3413B0C60>, < cv2.KeyPoint 000001F3413B0C90>, < cv2.KeyPoint 000001F3413B0CC0>, < cv2.KeyPoint 000001F3413B0CF0>, < cv2.KeyPoint 000001F3413B0D20>, < cv2.KeyPoint 000001F3413B0D50>, < cv2.KeyPoint 000001F3413B0D80>, < cv2.KeyPoint 000001F3413B0DB0>, < cv2.KeyPoint 000001F3413B0DE0>, < cv2.KeyPoint 000001F3413B0E10>, < cv2.KeyPoint 000001F3413B0E40>, < cv2.KeyPoint 000001F3413B0E70>, < cv2.KeyPoint 000001F3413B0EA0>, < cv2.KeyPoint 000001F3413B0ED0>, < cv2.KeyPoint 000001F3413B0F00>, < cv2.KeyPoint 000001F3413B0F30>, < cv2.KeyPoint 000001F3413B0F60>, < cv2.KeyPoint 000001F3413B0F90>, < cv2.KeyPoint 000001F3413B0FC0>, < cv2.KeyPoint 000001F3413C2030>, < cv2.KeyPoint 000001F3413C2060>, < cv2.KeyPoint 000001F3413C2090>, < cv2.KeyPoint 000001F3413C20C0>, < cv2.KeyPoint 000001F3413C20F0>, < cv2.KeyPoint 000001F3413C2120>, < cv2.KeyPoint 000001F3413C2150>, < cv2.KeyPoint 000001F3413C2180>, < cv2.KeyPoint 000001F3413C21B0>, < cv2.KeyPoint 000001F3413C21E0>, < cv2.KeyPoint 000001F3413C2210>, < cv2.KeyPoint 000001F3413C2240>, < cv2.KeyPoint 000001F3413C2270>, < cv2.KeyPoint 000001F3413C22A0>, < cv2.KeyPoint 000001F3413C22D0>, < cv2.KeyPoint 000001F3413C2300>, < cv2.KeyPoint 000001F3413C2330>, < cv2.KeyPoint 000001F3413C2360>, < cv2.KeyPoint 000001F3413C2390>, < cv2.KeyPoint 000001F3413C23C0>, < cv2.KeyPoint 000001F3413C23F0>, < cv2.KeyPoint 000001 ...

# %%
print(descriptors)
# Out:
# [[  1 177  27 ...   2 227 168]
#  [224  52 151 ...  97  71  35]
#  [208 233 190 ...  80 175  11]
#  ...
#  [118 233 150 ...  30 254 142]
#  [252 107 220 ... 249  76  42]
#  [ 63  82  70 ... 159  56  69]]
