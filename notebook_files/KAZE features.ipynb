# %%
import cv2
import matplotlib.pyplot as plt

# Load the input image
image_path = "E://1_DATASET//MICC//MICC_F600//_r30_s1200berries.png"  # Replace with the path to your image
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Check if the image is loaded successfully
if image is None:
    print("Error: Unable to load image. Check the path and try again.")
    exit()

# Initialize the KAZE detector
kaze = cv2.KAZE_create()

# Detect keypoints and compute descriptors
keypoints, descriptors = kaze.detectAndCompute(image, None)

# Draw the detected keypoints on the image
keypoints_image = cv2.drawKeypoints(
    image, keypoints, None, color=(0, 255, 0), flags=cv2.DrawMatchesFlags_DRAW_RICH_KEYPOINTS
)

# Display the image with keypoints
plt.figure(figsize=(10, 6))
plt.title("KAZE Keypoints")
plt.imshow(keypoints_image, cmap="gray")
plt.axis("off")
plt.show()

# Print the results
print(f"Number of keypoints detected: {len(keypoints)}")
if descriptors is not None:
    print(f"Descriptor shape: {descriptors.shape}")
else:
    print("No descriptors computed.")
# Out:
# Number of keypoints detected: 3620
# Descriptor shape: (3620, 64)

# %%
print(keypoints)
# Out:
# (< cv2.KeyPoint 000002820FA0F2A0>, < cv2.KeyPoint 0000028211293F90>, < cv2.KeyPoint 0000028211293930>, < cv2.KeyPoint 0000028211293960>, < cv2.KeyPoint 0000028211293900>, < cv2.KeyPoint 0000028211293FC0>, < cv2.KeyPoint 00000282112B58A0>, < cv2.KeyPoint 00000282199C0C60>, < cv2.KeyPoint 00000282199C0D50>, < cv2.KeyPoint 00000282199CD240>, < cv2.KeyPoint 000002821A0F9A20>, < cv2.KeyPoint 000002821A0F23F0>, < cv2.KeyPoint 000002821A11C9F0>, < cv2.KeyPoint 000002821A11CE40>, < cv2.KeyPoint 000002821A11CD20>, < cv2.KeyPoint 000002821A1280C0>, < cv2.KeyPoint 000002821A128060>, < cv2.KeyPoint 000002821A1280F0>, < cv2.KeyPoint 000002821A128210>, < cv2.KeyPoint 000002821A1281B0>, < cv2.KeyPoint 000002821A128270>, < cv2.KeyPoint 000002821A128240>, < cv2.KeyPoint 000002821A1282A0>, < cv2.KeyPoint 000002821A1282D0>, < cv2.KeyPoint 000002821A1283C0>, < cv2.KeyPoint 000002821A128300>, < cv2.KeyPoint 000002821A128330>, < cv2.KeyPoint 000002821A128390>, < cv2.KeyPoint 000002821A128360>, < cv2.KeyPoint 000002821A128030>, < cv2.KeyPoint 000002821A1281E0>, < cv2.KeyPoint 000002821A1283F0>, < cv2.KeyPoint 000002821A128450>, < cv2.KeyPoint 000002821A128420>, < cv2.KeyPoint 000002821A128480>, < cv2.KeyPoint 000002821A1284B0>, < cv2.KeyPoint 000002821A1284E0>, < cv2.KeyPoint 000002821A128510>, < cv2.KeyPoint 000002821A128540>, < cv2.KeyPoint 000002821A128570>, < cv2.KeyPoint 000002821A1285A0>, < cv2.KeyPoint 000002821A1285D0>, < cv2.KeyPoint 000002821A128600>, < cv2.KeyPoint 000002821A128630>, < cv2.KeyPoint 000002821A128660>, < cv2.KeyPoint 000002821A128690>, < cv2.KeyPoint 000002821A1286C0>, < cv2.KeyPoint 000002821A1286F0>, < cv2.KeyPoint 000002821A128720>, < cv2.KeyPoint 000002821A128750>, < cv2.KeyPoint 000002821A128780>, < cv2.KeyPoint 000002821A1287B0>, < cv2.KeyPoint 000002821A1287E0>, < cv2.KeyPoint 000002821A128810>, < cv2.KeyPoint 000002821A128840>, < cv2.KeyPoint 000002821A128870>, < cv2.KeyPoint 000002821A1288A0>, < cv2.KeyPoint 000002821A1288D0>, < cv2.KeyPoint 000002821A128900>, < cv2.KeyPoint 000002821A128930>, < cv2.KeyPoint 000002821A128960>, < cv2.KeyPoint 000002821A128990>, < cv2.KeyPoint 000002821A1289C0>, < cv2.KeyPoint 000002821A1289F0>, < cv2.KeyPoint 000002821A128A20>, < cv2.KeyPoint 000002821A128A50>, < cv2.KeyPoint 000002821A128A80>, < cv2.KeyPoint 000002821A128AB0>, < cv2.KeyPoint 000002821A128AE0>, < cv2.KeyPoint 000002821A128B10>, < cv2.KeyPoint 000002821A128B40>, < cv2.KeyPoint 000002821A128B70>, < cv2.KeyPoint 000002821A128BA0>, < cv2.KeyPoint 000002821A128BD0>, < cv2.KeyPoint 000002821A128C00>, < cv2.KeyPoint 000002821A128C30>, < cv2.KeyPoint 000002821A128C60>, < cv2.KeyPoint 000002821A128C90>, < cv2.KeyPoint 000002821A128CC0>, < cv2.KeyPoint 000002821A128CF0>, < cv2.KeyPoint 000002821A128D20>, < cv2.KeyPoint 000002821A128D50>, < cv2.KeyPoint 000002821A128D80>, < cv2.KeyPoint 000002821A128DB0>, < cv2.KeyPoint 000002821A128DE0>, < cv2.KeyPoint 000002821A128E10>, < cv2.KeyPoint 000002821A128E40>, < cv2.KeyPoint 000002821A128E70>, < cv2.KeyPoint 000002821A128EA0>, < cv2.KeyPoint 000002821A128ED0>, < cv2.KeyPoint 000002821A128F00>, < cv2.KeyPoint 000002821A128F30>, < cv2.KeyPoint 000002821A128F60>, < cv2.KeyPoint 000002821A128F90>, < cv2.KeyPoint 000002821A128FC0>, < cv2.KeyPoint 000002821A139030>, < cv2.KeyPoint 000002821A139060>, < cv2.KeyPoint 000002821A139090>, < cv2.KeyPoint 000002821A1390C0>, < cv2.KeyPoint 000002821A1390F0>, < cv2.KeyPoint 000002821A139120>, < cv2.KeyPoint 000002821A139150>, < cv2.KeyPoint 000002821A139180>, < cv2.KeyPoint 000002821A1391B0>, < cv2.KeyPoint 000002821A1391E0>, < cv2.KeyPoint 000002821A139210>, < cv2.KeyPoint 000002821A139240>, < cv2.KeyPoint 000002821A139270>, < cv2.KeyPoint 000002821A1392A0>, < cv2.KeyPoint 000002821A1392D0>, < cv2.KeyPoint 000002821A139300>, < cv2.KeyPoint 000002821A139330>, < cv2.KeyPoint 000002821A139360>, < cv2.KeyPoint 000002821A139390>, < cv2.KeyPoint 000002821A1393C0>, < cv2.KeyPoint 000002821A1393F0>, < cv2.KeyPoint 000002821A139420>, < cv2.KeyPoint 000002 ...

# %%
print(descriptors)
# Out:
# [[ 2.41824482e-02  1.10326214e-02  3.80888134e-02 ... -4.60074954e-02
#    3.38853225e-02  5.64343557e-02]
#  [-2.59521063e-02 -5.17690461e-03  7.39713609e-02 ...  1.82271339e-02
#    5.73931858e-02  4.06335220e-02]
#  [ 2.04008352e-02  6.61809966e-02  6.77742064e-02 ... -3.91915143e-02
#    7.92188272e-02  4.06036526e-02]
#  ...
#  [-2.04493869e-02  7.31302127e-02  7.13122934e-02 ... -2.35804617e-02
#    3.96173149e-02  7.09962919e-02]
#  [-8.76929890e-03 -2.50136405e-02  8.18279907e-02 ... -3.30307223e-02
#    7.32540861e-02  6.22734949e-02]
#  [ 1.41784685e-05  2.03226437e-03  3.63507755e-02 ... -5.47367288e-03
#    6.68391287e-02  9.15769935e-02]]
