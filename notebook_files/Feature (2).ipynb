# %% [markdown]
# import kagglehub
#
# Download latest version
# path = kagglehub.dataset_download("nishaahin/miccf600")
#
# print("Path to dataset files:", path)
#
# prompt: I want to add the dataset in this notebook that is in zip format
#
# import zipfile
#
# Assuming 'path' variable holds the path to the downloaded zip file
# with zipfile.ZipFile(path, 'r') as zip_ref:
#     zip_ref.extractall('./extracted_dataset')
#
# Now the dataset files are extracted to the 'extracted_dataset' folder.

# %% [markdown]
# #I. Amerini, L. Ballan, R. Caldelli, A. Del Bimbo, G. Serra. “A SIFT-based forensic method for copy-move attack detection and transformation recovery”, IEEE Transactions on Information Forensics and Security, vol. 6, issue 3, pp. 1099-1110, 2011.
# # Dataset reference

# %% [markdown]
# BRISK FEATURE

# %%
# BRISK FEATURES

import cv2
import matplotlib.pyplot as plt

# Load the input image
image_path = "/content/_r30_s1200berries.png"  # Replace with the path to your image
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Check if the image is loaded successfully
if image is None:
    print("Error: Unable to load image. Check the path and try again.")
    exit()

# Initialize the BRISK detector
brisk = cv2.BRISK_create()

# Detect keypoints and compute descriptors
keypoints, descriptors = brisk.detectAndCompute(image, None)

# Draw the detected keypoints on the image
keypoints_image = cv2.drawKeypoints(
    image, keypoints, None, color=(0, 255, 0), flags=cv2.DrawMatchesFlags_DRAW_RICH_KEYPOINTS
)

# Display the image with keypoints
plt.figure(figsize=(10, 6))
plt.title("BRISK Keypoints")
plt.imshow(keypoints_image, cmap="gray")
plt.axis("off")
plt.show()

# Print the results
print(f"Number of keypoints detected: {len(keypoints)}")
if descriptors is not None:
    print(f"Descriptor shape: {descriptors.shape}")
else:
    print("No descriptors computed.")
# Out:
# Number of keypoints detected: 1536
# Descriptor shape: (1536, 64)

# %%
print(keypoints)
# Out:
# (< cv2.KeyPoint 0x787f1b085fe0>, < cv2.KeyPoint 0x787f1b0850b0>, < cv2.KeyPoint 0x787ef5191770>, < cv2.KeyPoint 0x787ef51916e0>, < cv2.KeyPoint 0x787ef5191710>, < cv2.KeyPoint 0x787ef5193930>, < cv2.KeyPoint 0x787ef51939f0>, < cv2.KeyPoint 0x787ef51939c0>, < cv2.KeyPoint 0x787ef5193960>, < cv2.KeyPoint 0x787ef51938d0>, < cv2.KeyPoint 0x787ef51d8030>, < cv2.KeyPoint 0x787ef51d8060>, < cv2.KeyPoint 0x787ef51d8090>, < cv2.KeyPoint 0x787ef51d80c0>, < cv2.KeyPoint 0x787ef51d80f0>, < cv2.KeyPoint 0x787ef51d8120>, < cv2.KeyPoint 0x787ef51d8150>, < cv2.KeyPoint 0x787ef51d8180>, < cv2.KeyPoint 0x787ef51d81b0>, < cv2.KeyPoint 0x787ef51d81e0>, < cv2.KeyPoint 0x787ef51d8210>, < cv2.KeyPoint 0x787ef51d8240>, < cv2.KeyPoint 0x787ef51d8270>, < cv2.KeyPoint 0x787ef51d82a0>, < cv2.KeyPoint 0x787ef51d82d0>, < cv2.KeyPoint 0x787ef51d8300>, < cv2.KeyPoint 0x787ef51d8330>, < cv2.KeyPoint 0x787ef51d8360>, < cv2.KeyPoint 0x787ef51d8390>, < cv2.KeyPoint 0x787ef51d83c0>, < cv2.Key
Point 0x787ef51d9050>, < cv2.KeyPoint 0x787ef51d9080>, < cv2.KeyPoint 0x787ef51d90b0>, < cv2.KeyPoint 0x787ef51d90e0>, < cv2.KeyPoint 0x787ef51d9110>, < cv2.KeyPoint 0x787ef51d9140>, < cv2.KeyPoint 0x787ef51d9170>, < cv2.KeyPoint 0x787ef51d91a0>, < cv2.KeyPoint 0x787ef51d91d0>, < cv2.KeyPoint 0x787ef51d9200>, < cv2.KeyPoint 0x787ef51d9230>, < cv2.KeyPoint 0x787ef51d9260>, < cv2.KeyPoint 0x787ef51d9290>, < cv2.KeyPoint 0x787ef51d92c0>, < cv2.KeyPoint 0x787ef51d92f0>, < cv2.KeyPoint 0x787ef51d9320>, < cv2.KeyPoint 0x787ef51d9350>, < cv2.KeyPoint 0x787ef51d9380>, < cv2.KeyPoint 0x787ef51d93b0>, < cv2.KeyPoint 0x787ef51d93e0>, < cv2.KeyPoint 0x787ef51d9410>, < cv2.KeyPoint 0x787ef51d9440>, < cv2.KeyPoint 0x787ef51d9470>, < cv2.KeyPoint 0x787ef51d94a0>, < cv2.KeyPoint 0x787ef51d94d0>, < cv2.KeyPoint 0x787ef51d9500>, < cv2.KeyPoint 0x787ef51d9530>, < cv2.KeyPoint 0x787ef51d9560>, < cv2.KeyPoint 0x787ef51d9590>, ...

# %%
print(descriptors)
# Out:
# [[  0 114 223 ...  71  22  16]
#  [180 123 223 ... 207 159  16]
#  [180  27 223 ...  12  25  50]
#  ...
#  [254 252 255 ... 205 156 223]
#  [223 174  37 ... 239 110 237]
#  [107 245 190 ...  56  56 252]]

# %% [markdown]
# KAZE FEATURE

# %%
import cv2
import matplotlib.pyplot as plt

# Load the input image
image_path = "/content/_r30_s1200berries.png"    # Replace with the path to your image
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Check if the image is loaded successfully
if image is None:
    print("Error: Unable to load image. Check the path and try again.")
    exit()

# Initialize the KAZE detector
kaze = cv2.KAZE_create()

# Detect keypoints and compute descriptors
keypoints, descriptors = kaze.detectAndCompute(image, None)

# Draw the detected keypoints on the image
keypoints_image = cv2.drawKeypoints(
    image, keypoints, None, color=(0, 255, 0), flags=cv2.DrawMatchesFlags_DRAW_RICH_KEYPOINTS
)

# Display the image with keypoints
plt.figure(figsize=(10, 6))
plt.title("KAZE Keypoints")
plt.imshow(keypoints_image, cmap="gray")
plt.axis("off")
plt.show()

# Print the results
print(f"Number of keypoints detected: {len(keypoints)}")
if descriptors is not None:
    print(f"Descriptor shape: {descriptors.shape}")
else:
    print("No descriptors computed.")
# Out:
# Number of keypoints detected: 3620
# Descriptor shape: (3620, 64)

# %%
print(keypoints)
# Out:
# (< cv2.KeyPoint 0x787ef4dabfc0>, < cv2.KeyPoint 0x787ef4daa6a0>, < cv2.KeyPoint 0x787ef4da9ef0>, < cv2.KeyPoint 0x787ef4dabe40>, < cv2.KeyPoint 0x787ef4da84b0>, < cv2.KeyPoint 0x787ef4daa4c0>, < cv2.KeyPoint 0x787ef4daaa90>, < cv2.KeyPoint 0x787ef4dabea0>, < cv2.KeyPoint 0x787ef4daa490>, < cv2.KeyPoint 0x787ef4dabcf0>, < cv2.
# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature import local_binary_pattern
from skimage.color import label2rgb

# Parameters for LBP
radius = 1  # Radius of the circular neighborhood
n_points = 8 * radius  # Number of points in the neighborhood

# Load the input image
image_path = "/content/_r30_s1200berries.png"    # Replace with your image path
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Check if the image is loaded successfully
if image is None:
    print("Error: Unable to load image. Check the path and try again.")
    exit()

# Compute LBP features
lbp = local_binary_pattern(image, n_points, radius, method="uniform")

# Create a histogram of the LBP features
lbp_hist, _ = np.histogram(lbp.ravel(), bins=np.arange(0, n_points + 3), range=(0, n_points + 2))

# Normalize the histogram
lbp_hist = lbp_hist.astype("float")
lbp_hist /= (lbp_hist.sum() + 1e-6)

# Visualize the LBP image
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(image, cmap="gray")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.title("LBP Image")
plt.imshow(lbp, cmap="gray")
plt.axis("off")

plt.show()

# Print the normalized LBP histogram
print("Normalized LBP Histogram:")
print(lbp_hist)
# Out:
# Normalized LBP Histogram:
# [0.0233404  0.04786534 0.01831193 0.119581   0.19094865 0.19808102
#  0.07994989 0.07883627 0.13937417 0.10371134]

# %%
print(lbp[0])
# Out:
# [3. 2. 3. ... 3. 5. 2.]

# %%
if hasattr(cv2, 'xfeatures2d'):
    print("SURF is available!")
    surf = cv2.xfeatures2d.SURF_create()
else:
    print("SURF is not available.")
# Out:
# SURF is available!
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-9-eda95cb6069f> in <cell line: 0>()
#       1 if hasattr(cv2, 'xfeatures2d'):
#       2     print("SURF is available!")
# ----> 3     surf = cv2.xfeatures2d.SURF_create()
#       4 else:
#       5     print("SURF is not available.")
#
# error: OpenCV(4.11.0) /io/opencv_contrib/modules/xfeatures2d/src/surf.cpp:1026: error: (-213:The function/feature is not implemented) This algorithm is patented and is excluded in this configuration; Set OPENCV_ENABLE_NONFREE CMake option and rebuild the library in function 'create'

# %%
from platform import python_version

print(python_version())
# Out:
# 3.11.11

# %% [markdown]
# ORB FEATURE

# %%
import cv2
import matplotlib.pyplot as plt

# Load the input image
image_path = "/content/_r30_s1200berries.png"
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Check if the image is loaded
if image is None:
    print("Error: Image not loaded. Please check the path.")
    exit()

# Create an ORB detector
orb = cv2.ORB_create()

# Detect keypoints and compute descriptors
keypoints, descriptors = orb.detectAndCompute(image, None)

# Draw the keypoints on the image
keypoints_image = cv2.drawKeypoints(image, keypoints, None, color=(0, 255, 0), flags=0)

# Display the original image with keypoints
plt.figure(figsize=(10, 6))
plt.title("ORB Keypoints")
plt.imshow(keypoints_image, cmap='gray')
plt.axis("off")
plt.show()

# Print the number of keypoints and descriptors
print(f"Number of keypoints detected: {len(keypoints)}")
if descriptors is not None:
    print(f"Descriptor shape: {descriptors.shape}")
else:
    print("No descriptors computed.")
# Out:
# Number of keypoints detected: 500
# Descriptor shape: (500, 32)

# %%
print(keypoints)
# Out:
# (< cv2.KeyPoint 0x787edddda130>, < cv2.KeyPoint 0x787edddda4c0>, < cv2.KeyPoint 0x787edddda760>, < cv2.KeyPoint 0x787edddda6d0>, < cv2.KeyPoint 0x787edddda160>, < cv2.KeyPoint 0x787edddda5e0>, < cv2.KeyPoint 0x787edddda670>, < cv2.KeyPoint 0x787edddda1c0>, < cv2.KeyPoint 0x787eddddaf70>, < cv2.KeyPoint 0x787eddddaaf0>, < cv2.KeyPoint 0x787eddddb3f0>, < cv2.KeyPoint 0x
KeyPoint 0x787edddc70c0>, < cv2.KeyPoint 0x787edddc5a40>, < cv2.KeyPoint 0x787edddc6820>, < cv2.KeyPoint 0x787edddc7330>, < cv2.KeyPoint 0x787edddc7300>, < cv2.KeyPoint 0x787edddc72d0>, < cv2.KeyPoint 0x787edddc72a0>, < cv2.KeyPoint 0x787edddc7270>, < cv2.KeyPoint 0x787edddc7240>, < cv2.KeyPoint 0x787edddc7210>, < cv2.KeyPoint 0x787edddc71e0>, < cv2.KeyPoint 0x787edddc71b0>, < cv2.KeyPoint 0x787edddc5470>, < cv2.KeyPoint 0x787edddc54a0>, < cv2.KeyPoint 0x787edddc54d0>, < cv2.KeyPoint 0x787edddc5500>, < cv2.KeyPoint 0x787edddc5530>, < cv2.KeyPoint 0x787edddc5560>, < cv2.KeyPoint 0x787edddc5590>, < cv2.KeyPoint 0x787edddc55c0>, < cv2.KeyPoint 0x787edddc55f0>, < cv2.KeyPoint 0x787edddc5620>, < cv2.KeyPoint 0x787edddc5650>, < cv2.KeyPoint 0x787edddc5680>, < cv2.KeyPoint 0x787edddc56b0>, < cv2.KeyPoint 0x787edddc56e0>, < cv2.KeyPoint 0x787edddc5710>, < cv2.KeyPoint 0x787edddc5740>, < cv2.KeyPoint 0x787edddc5770>, < cv2.KeyPoint 0x787edddc57a0>, < cv2.KeyPoint 0x787edddc57d0>, < cv2.KeyPoint 0x787edddc5800>, < cv2.KeyPoint 0x787edddc6e20>, < cv2.KeyPoint 0x787edddc6e50>, < cv2.KeyPoint 0x787edddc6ee0>, < cv2.KeyPoint 0x787edddc6f10>, < cv2.KeyPoint 0x787edddc4a20>, < cv2.KeyPoint 0x787edddc4990>, < cv2.KeyPoint 0x787edddc4930>, < cv2.KeyPoint 0x787edddc4960>, < cv2.KeyPoint 0x787edddc49c0>, < cv2.KeyPoint 0x787edddc49f0>, < cv2.KeyPoint 0x787edddc4900>, < cv2.KeyPoint 0x787edddc48d0>, < cv2.KeyPoint 0x787edddc48a0>, < cv2.KeyPoint 0x787edddc4870>, < cv2.KeyPoint 0x787edddc4840>, ...

# %%
print(descriptors)
# Out:
# [[133 126 157 ... 243  66  33]
#  [248 190 158 ... 192 142  75]
#  [224  52 151 ...  97  71  35]
#  ...
#  [ 82  72 210 ... 120 122  14]
#  [252 107 220 ... 249  76  42]
#  [ 63  82  70 ... 159  56  69]]

# %% [markdown]
# SIFT FEATURE

# %%
import cv2
from matplotlib import pyplot as plt

# Load an image
image = cv2.imread('_r30_s1200berries.png')

# Resize the image using OpenCV's resize function
image = cv2.resize(image, (480, 480))

# Initialize the SIFT detector
sift = cv2.SIFT_create()

# Detect keypoints and compute descriptors
keypoints, descriptors = sift.detectAndCompute(image, None)

# Draw keypoints on the image
image_with_keypoints = cv2.drawKeypoints(image, keypoints, None)

# Save the output image
cv2.imwrite('SIFT_output_image.png', image_with_keypoints)

# Convert BGR to RGB for correct color rendering in matplotlib
image_with_keypoints_rgb = cv2.cvtColor(image_with_keypoints, cv2.COLOR_BGR2RGB)

# Display the image using matplotlib
plt.imshow(image_with_keypoints_rgb)
plt.axis('off')  # Hide axes for better visualization
plt.title("Image with SIFT Keypoints")
plt.show()
